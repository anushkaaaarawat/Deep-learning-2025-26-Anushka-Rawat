# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkaaaarawat/Deep-learning-2025-26-Anushka-Rawat/blob/main/Linear_Regression_sample_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Example dataset (Weight in kg, Height in cm)
weight = np.array([50, 60, 70, 80, 90, 100]).reshape(-1, 1)
height = np.array([150, 155, 160, 165, 170, 175])

# Create and train the model
model = LinearRegression()
model.fit(weight, height)

# User input for weight
user_weight = float(input("Enter weight in kg: "))

# Predict height
predicted_height = model.predict([[user_weight]])
print(f"Predicted Height for {user_weight} kg: {predicted_height[0]:.2f} cm")
# Out:
# Enter weight in kg: 70
# Predicted Height for 70.0 kg: 160.00 cm

# %%
import pandas as pd
df = pd.read_csv('tvmarketing.csv')

# %%
df.head(100)
# Out:
#        TV  Sales
# 0   230.1   22.1
# 1    44.5   10.4
# 2    17.2    9.3
# 3   151.5   18.5
# 4   180.8   12.9
# ..    ...    ...
# 95  163.3   16.9
# 96  197.6   11.7
# 97  184.9   15.5
# 98  289.7   25.4
# 99  135.2   17.2
#
# [100 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
df.shape
# Out:
# (200, 2)

# %%
df.plot(x='TV',y='Sales',kind='scatter')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
X = df['TV'].values.reshape(-1, 1)

# Print the first 5 rows
print(X[:5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3915664377.py in <cell line: 0>()
# ----> 1 X = df['TV'].reshape(0,-1)
#       2
#       3 # Print the first 5 rows
#       4 X.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
y = df['Sales']

# Print the first 5 rows
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7 , random_state=42)

# %%
print(type(X_train))
print(type(X_test))
print(type(y_train))
print(type(y_test))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3537677330.py in <cell line: 0>()
# ----> 1 X_train = X_train.values.reshape(-1, 1)
#       2 X_test = X_test.values.reshape(-1, 1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
# import LinearRegression from sklearn
from sklearn.linear_model import LinearRegression

# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()
# Fit the model using lr.fit()
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-710735058.py in <cell line: 0>()
#       5 lr = LinearRegression()
#       6 # Fit the model using lr.fit()
# ----> 7 lr.fit(X_train, y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# ...

# %%
# Print the intercept and coefficients
print(lr.intercept_)
print(lr.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3696205543.py in <cell line: 0>()
#       1 # Print the intercept and coefficients
# ----> 2 print(lr.intercept_)
#       3 print(lr.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'
